# %%
pip install pytrends matplotlib pandas seaborn plotly
# Out:
# Requirement already satisfied: pytrends in c:\users\prajwal chichansure\anaconda3\lib\site-packages (4.9.2)
# Requirement already satisfied: matplotlib in c:\users\prajwal chichansure\anaconda3\lib\site-packages (3.8.4)
# Requirement already satisfied: pandas in c:\users\prajwal chichansure\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: seaborn in c:\users\prajwal chichansure\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: plotly in c:\users\prajwal chichansure\anaconda3\lib\site-packages (5.22.0)
# Requirement already satisfied: requests>=2.0 in c:\users\prajwal chichansure\appdata\roaming\python\python312\site-packages (from pytrends) (2.32.3)
# Requirement already satisfied: lxml in c:\users\prajwal chichansure\anaconda3\lib\site-packages (from pytrends) (5.2.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\prajwal chichansure\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\prajwal chichansure\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\prajwal chichansure\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\prajwal chichansure\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.21 in c:\users\prajwal chichansure\anaconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\prajwal chichansure\appdata\roaming\python\python312\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\prajwal chichansure\anaconda3\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\prajwal chichansure\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\prajwal chichansure\appdata\roaming\python\python312\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\prajwal chichansure\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\prajwal chichansure\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\prajwal chichansure\anaconda3\lib\site-packages (from plotly) (8.2.2)
# Requirement already satisfied: six>=1.5 in c:\users\prajwal chichansure\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\prajwal chichansure\appdata\roaming\python\python312\site-packages (from requests>=2.0->pytrends) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\prajwal chichansure\appdata\roaming\python\python312\site-packages (from requests>=2.0->pytrends) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\prajwal chichansure\appdata\roaming\python\python312\site-packages (from requests>=2.0->pytrends) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\prajwal chichansure\appdata\roaming\python\python312\site-packages (from requests>=2.0->pytrends) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: C:\Users\prajwal chichansure\anaconda3\python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from pytrends.request import TrendReq

# %% [markdown]
# # setup pytrend library and keyword define

# %%
pytrends = TrendReq(hl = 'en-US', tz = 360)
keyword = "Machine Learning"

# %% [markdown]
# # Data Request

# %%
pytrends.build_payload([keyword], cat = 0, timeframe = 'today 12-m',geo='', gprop = '')

# %% [markdown]
# # country wise interest

# %%
region_data = pytrends.interest_by_region()
region_data = region_data.sort_values(by = keyword,ascending = False).head(15)

# %%
plt.figure(figsize = (10,6))
sns.barplot(x = region_data[keyword], y = region_data.index, palette = "Blues_d")
plt.title(f"Top Countries searching for '{keyword}' ")
plt.xlabel("Interest")
plt.ylabel("Country")
plt.show()
# Out:
# C:\Users\prajwal chichansure\AppData\Local\Temp\ipykernel_13632\4237842116.py:2: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# # World Map

# %%
region_data = region_data.reset_index()
fig = px.choropleth(region_data,
                    locations='geoName',
                    locationmode='country names',
                    color=keyword,
                    title=f"Search Interest for '{keyword}' by Country",
                    color_continuous_scale='Blues')
fig.show()

# %% [markdown]
# # time wise interest

# %%
time_df = pytrends.interest_over_time()
# Out:
# C:\Users\prajwal chichansure\anaconda3\Lib\site-packages\pytrends\request.py:260: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`

# %%
plt.figure(figsize=(12,6))
plt.plot(time_df.index, time_df[keyword], marker = 'o', color = 'purple')
plt.title(f"search interest over time '{keyword}' ")
plt.xlabel("Date")
plt.ylabel("Interest")
plt.grid(True)
plt.show()

# %% [markdown]
# # multiple keywords compare

# %%
kw_list = ["Machine Learning","Cyber Security","Data Science"]
pytrends.build_payload(kw_list, cat= 0, timeframe = 'today 12-m',geo ='',gprop='')

# %%
compare_df = pytrends.interest_over_time()


plt.figure(figsize=(12,6))
for kw in kw_list:
    plt.plot(compare_df.index, compare_df[kw], label = kw)

plt.title("keyword comparison over time")
plt.xlabel("Date")
plt.ylabel("Interest")
plt.legend()
plt.tight_layout()
plt.grid(True)
plt.show()
# Out:
# C:\Users\prajwal chichansure\anaconda3\Lib\site-packages\pytrends\request.py:260: FutureWarning:
#
# Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
